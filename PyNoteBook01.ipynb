# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Created by Corneliu Ungureanu, Data Scientist

# %% [markdown]
# _I am interested in Data Science because it can really have an impact on the modern world making it better hopefully_

# %% [markdown]
# ### The following line makes some basic arithmetic calculations

# %%
3 * 5 + 5
# Out:
# 20
